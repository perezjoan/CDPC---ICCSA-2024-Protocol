# %%
# EMC2 WP 2 Processing 0.1
# GeoPackage : Department preparation
# BD_TOPO (Building, roads, administrative limits and activity areas),
# Filosofi (population)
# Author : Perez Joan

# Download : last version of BD_TOPO for a given French department (BD TOPO® décembre 2023 Tous Thèmes par département format GeoPackage projection légale)
# Webpage : https://geoservices.ign.fr/bdtopo#telechargementgpkgreg
# Example of chosen department : Alpes maritimes (06)
# https://data.geopf.fr/telechargement/download/BDTOPO/BDTOPO_3-3_TOUSTHEMES_GPKG_LAMB93_D006_2023-12-15/BDTOPO_3-3_TOUSTHEMES_GPKG_LAMB93_D006_2023-12-15.7z

# Download : last version of Filosofi (2019)
# https://www.insee.fr/fr/statistiques/7655475?sommaire=7655515

# %%
# 0.1 Packages, local filepaths & parameters
import os
import pandas
import geopandas
import time

# Set filepaths to downloaded data
BD_TOPO = "C:\\Users\\jperez\\Documents\\Current 1\\emc2\\Raw data\\BDTOPO 3-3\\1_DONNEES_LIVRAISON_2023-12-00191\\BDT_3-3_GPKG_LAMB93_D006-ED2023-12-15\\BDT_3-3_GPKG_LAMB93_D006-ED2023-12-15.gpkg"
Filosofi = "C:\\Users\\jperez\\Documents\\Current 1\\emc2\\Raw data\\Filosofi 2019\\carreaux_200m_met.shp"

# Specify the file path to record the main gpkg file
main_gpkg = "C:\\Users\\jperez\\Documents\\Current 1\\emc2\\Output\\WP2_DPC_0.1.gpkg"

# %%
## 1. load raw data

# Read the administrative boundaries
start_time = time.time()
administrative = geopandas.read_file(BD_TOPO, layer="commune", engine='pyogrio', use_arrow=True)
# Read roads
road = geopandas.read_file(BD_TOPO, layer="troncon_de_route", engine='pyogrio', use_arrow=True)
# Read buildings
building = geopandas.read_file(BD_TOPO, layer="batiment", engine='pyogrio', use_arrow=True)
# Read activity areas
activity_area = geopandas.read_file(BD_TOPO, layer="zone_d_activite_ou_d_interet", engine='pyogrio', use_arrow=True)
# Read population
population = geopandas.read_file(Filosofi, engine='pyogrio', use_arrow=True)
end_time = time.time()
print("Import processing time:", end_time - start_time, "seconds")
# Out:
# Import processing time: 53.976741790771484 seconds

# %%
## 2. Clean data

# Keep population squares for given department only
dpt_population = geopandas.sjoin(population, administrative, predicate='within')
dpt_population = dpt_population.iloc[:, list(range(35))]

# Remove variables with wrong format in BD_TOPO datasets (compatibility issues with geopandas
administrative_clean = administrative.iloc[:, list(range(8)) + list(range(12, 19)) + list(range(20, 26))]
building_clean = building.iloc[:, list(range(6)) + list(range(10, 28))]
road_clean = road.iloc[:, list(range(8)) + list(range(12, 44)) + list(range(45, 85))]
activity_area_clean = activity_area.iloc[:, list(range(9)) + list(range(13, 20))]

# %%
## 4. Create GPKG for downloaded department & subset

# Save the GeoDataFrames to a gpkg file
dpt_population.to_file(main_gpkg, layer = "population", driver="GPKG")
building_clean.to_file(main_gpkg, layer = "building", driver="GPKG")
road_clean.to_file(main_gpkg, layer = "road", driver="GPKG")
administrative_clean.to_file(main_gpkg, layer = "administrative", driver="GPKG")
activity_area_clean.to_file(main_gpkg, layer = "activity_areas", driver="GPKG")

# %%
# Appendices
import contextily
import matplotlib.pyplot as plt

# %%
# Appendix A1 : check : population filter (Filosofi) on given department
ax = dpt_population.plot(figsize=(9, 9))
# Add basemap
contextily.add_basemap(ax, crs=dpt_population.crs, source=contextily.providers.CartoDB.Voyager)
# Manually create legend handles and labels
legend_handles = [plt.Rectangle((0, 0), 1, 1, color='lightblue')]
legend_labels = ["Population data available"]
# Add custom legend
ax.legend(legend_handles, legend_labels)
plt.show()

# %%
# Appendix A2 : check column names & indexes before/after removal of columns
before = road # layer name
for index, column_name in enumerate(before.columns):
    print(f"Column {index}: {column_name}")
after = road_clean # layer name
for index, column_name in enumerate(after.columns):
    print(f"Column {index}: {column_name}")
# Out:
# Column 0: cleabs
# Column 1: nature
# Column 2: nom_collaboratif_gauche
# Column 3: nom_collaboratif_droite
# Column 4: importance
# Column 5: fictif
# Column 6: position_par_rapport_au_sol
# Column 7: etat_de_l_objet
# Column 8: date_creation
# Column 9: date_modification
# Column 10: date_d_apparition
# Column 11: date_de_confirmation
# Column 12: sources
# Column 13: identifiants_sources
# Column 14: methode_d_acquisition_planimetr
# Column 15: precision_planimetrique
# Column 16: methode_d_acquisition_altimetri
# Column 17: precision_altimetrique
# Column 18: nombre_de_voies
# Column 19: largeur_de_chaussee
# Column 20: itineraire_vert
# Column 21: prive
# Column 22: sens_de_circulation
# Column 23: reserve_aux_bus
# Column 24: urbain
# Column 25: vitesse_moyenne_vl
# Column 26: acces_vehicule_leger
# Column 27: acces_pieton
# Column 28: periode_de_fermeture
# Column 29: nature_de_la_restriction
# Column 30: restriction_de_hauteur
# Column 31: restriction_de_poids_total
# Column 32: restriction_de_poids_par_essieu
# Column 33: restriction_de_largeur
# Column 34: restriction_de_longueur
# Column 35: matieres_dangereuses_interdites
# Column 36: borne_debut_gauche
# Column 37: borne_debut_droite
# Column 38: borne_fin_gauche
# Column 39: borne_fin_droite
# Column 40: insee_commune_gauche
# Column 41: insee_commune_droite
# Column 42: alias_gauche
# Column 43: alias_droit
# Column 44: date_de_mise_en_service
# Column 45: identifiant_voie_1_gauche
# Column 46: identifiant_voie_1_droite
# Column 47: liens_vers_route_nommee
# Column 48: liens_vers_itineraire_autre
# Column 49: cpx_numero
# Column 50: cpx_numero_route_europeenne
# Column 51: cpx_classement_administratif
# Column 52: cpx_gestionnaire
# Column 53: cpx_toponyme_route_nommee
# Column 54: cpx_toponyme_itineraire_cyclabl
# Column 55: cpx_toponyme_voie_verte
# Column 56: cpx_nature_itineraire_autre
# Column 57: cpx_toponyme_itineraire_autre
# Column 58: delestage
# Column 59: source_voie_ban_gauche
# Column 60: source_voie_ban_droite
# Column 61: nom_voie_ban_gauche
# Column 62: nom_voie_ban_droite
# Column 63: lieux_dits_ban_gauche
# Column 64: lieux_dits_ban_droite
# Column 65: identifiant_voie_ban_gauche
# Column 66: identifiant_voie_ban_droite
# Column 67: sens_amenagement_cyclable_gauch
# Column 68: sens_amenagement_cyclable_droit
# Column 69: amenagement_cyclable_gauche
# Column 70: amenagement_cyclable_droit
# Column 71: aire_de_retournement_dfci
# Column 72: gabarit_dfci
# Column 73: impasse_dfci
# Column 74: nature_detaillee_dfci
# Column 75: ouvrage_d_art_limitant_dfci
# Column 76: pente_maximale_dfci
# Column 77: piste_dfci
# Column 78: piste_dfci_debroussaillee
# Column 79: piste_dfci_fosses
# Column 80: sens_de_circulation_dfci
# Column 81: tout_terrain_dfci
# Column 82: vitesse_moyenne_dfci
# Column 83: zone_de_croisement_dfci
# Column 84: geometry
# Column 0: cleabs
# Column 1: nature
# Column 2: nom_collaboratif_gauche
# Column 3: nom_collaboratif_droite
# Column 4: importance
# Column 5: fictif
# Column 6: position_par_rapport_au_sol
# Column 7: etat_de_l_objet
# Column 8: sources
# Column 9: identifiants_sources
# Column 10: methode_d_acquisition_planimetr
# Column 11: precision_planimetrique
# Column 12: methode_d_acquisition_altimetri
# Column 13: precision_altimetrique
# Column 14: nombre_de_voies
# Column 15: largeur_de_chaussee
# Column 16: itineraire_vert
# Column 17: prive
# Column 18: sens_de_circulation
# Column 19: reserve_aux_bus
# Column 20: urbain
# Column 21: vitesse_moyenne_vl
# Column 22: acces_vehicule_leger
# Column 23: acces_pieton
# Column 24: periode_de_fermeture
# Column 25: nature_de_la_restriction
# Column 26: restriction_de_hauteur
# Column 27: restriction_de_poids_total
# Column 28: restriction_de_poids_par_essieu
# Column 29: restriction_de_largeur
# Column 30: restriction_de_longueur
# Column 31: matieres_dangereuses_interdites
# Column 32: borne_debut_gauche
# Column 33: borne_debut_droite
# Column 34: borne_fin_gauche
# Column 35: borne_fin_droite
# Column 36: insee_commune_gauche
# Column 37: insee_commune_droite
# Column 38: alias_gauche
# Column 39: alias_droit
# Column 40: identifiant_voie_1_gauche
# Column 41: identifiant_voie_1_droite
# Column 42: liens_vers_route_nommee
# Column 43: liens_vers_itineraire_autre
# Column 44: cpx_numero
# Column 45: cpx_numero_route_europeenne
# Column 46: cpx_classement_administratif
# Column 47: cpx_gestionnaire
# Column 48: cpx_toponyme_route_nommee
# Column 49: cpx_toponyme_itineraire_cyclabl
# Column 50: cpx_toponyme_voie_verte
# Column 51: cpx_nature_itineraire_autre
# Column 52: cpx_toponyme_itineraire_autre
# Column 53: delestage
# Column 54: source_voie_ban_gauche
# Column 55: source_voie_ban_droite
# Column 56: nom_voie_ban_gauche
# Column 57: nom_voie_ban_droite
# Column 58: lieux_dits_ban_gauche
# Column 59: lieux_dits_ban_droite
# Column 60: identifiant_voie_ban_gauche
# Column 61: identifiant_voie_ban_droite
# Column 62: sens_amenagement_cyclable_gauch
# Column 63: sens_amenagement_cyclable_droit
# Column 64: amenagement_cyclable_gauche
# Column 65: amenagement_cyclable_droit
# Column 66: aire_de_retournement_dfci
# Column 67: gabarit_dfci
# Column 68: impasse_dfci
# Column 69: nature_detaillee_dfci
# Column 70: ouvrage_d_art_limitant_dfci
# Column 71: pente_maximale_dfci
# Column 72: piste_dfci
# Column 73: piste_dfci_debroussaillee
# Column 74: piste_dfci_fosses
# Column 75: sens_de_circulation_dfci
# Column 76: tout_terrain_dfci
# Column 77: vitesse_moyenne_dfci
# Column 78: zone_de_croisement_dfci
# Column 79: geometry
